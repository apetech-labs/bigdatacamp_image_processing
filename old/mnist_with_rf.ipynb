# %%
import numpy as np
from time import process_time
import matplotlib.pyplot as plt
from keras.datasets import mnist
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# #Load MNIST Dataset

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
prt = 'ground truth %d' % y_train[0]
plt.title(prt)
plt.imshow(x_train[0], 'gray')
plt.show()

# %% [markdown]
# #convert to 1d

# %%
RESHAPED = 28*28*1
x_train = x_train.reshape(60000, RESHAPED)
x_test = x_test.reshape(10000, RESHAPED)

# %%
x_train.shape, x_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
proba_test = np.zeros((y_test.shape[0], len(np.unique(y_test))))
proba_train = np.zeros((y_train.shape[0], len(np.unique(y_train))))

# %%
sequence = 1

# %%
model = LGBMClassifier(n_estimators=sequence)

# %% [markdown]
# Model Fit(학습) 진행.

# %%
t0 = process_time()
model.fit(x_train, y_train)
# Out:
# LGBMClassifier(n_estimators=10)

# %%
test_score = accuracy_score(y_test, model.predict(x_test))
train_score= accuracy_score(y_train, model.predict(x_train))

# %%
test_score, train_score
# Out:
# (0.9371, 0.94735)

# %%
test_pred = model.predict(x_test)

# %%
for it_sample, draw in enumerate(x_test[:100]):
  # if y_test[it_sample] != test_pred[it_sample]:
  prt = 'ground truth %d, predict %d' % (y_test[it_sample], test_pred[it_sample] )
  plt.title(prt)
  plt.imshow(draw.reshape(28, 28, 1), 'gray')
  plt.show()
